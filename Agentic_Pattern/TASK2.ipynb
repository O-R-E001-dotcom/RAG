# %%
import operator
from typing import Annotated, List, TypedDict, Literal
from langchain_core.messages import HumanMessage
from langgraph.graph import StateGraph, START, END
import os
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI

# %%
# Load API key
load_dotenv()
openai_api_key = os.getenv("OPENAI_API_KEY")

if not openai_api_key:
    raise ValueError("OPENAI_API_KEY not found!")

print("✅ API key loaded")
# Out:
# ✅ API key loaded

# %%
# Initialize LLM
llm = ChatOpenAI(
    model="gpt-4o-mini",
    temperature=0,
    api_key=openai_api_key
)

print(f"✅ LLM initialized: {llm.model_name}")
# Out:
# ✅ LLM initialized: gpt-4o-mini

# %%
# State for the Hybrid Agent
class HybridState(TypedDict):
    input: str
    plan: List[str]
    current_step: int
    results: Annotated[List[str], operator.add]
    
    # Reflection fields
    draft: str
    critique: str
    iterations: int
    final_output: str

MAX_REFLECTIONS = 2

# %%
# Node 1: Planner
def planner(state: HybridState) -> dict:
    """Create a step-by-step plan."""
    prompt = f"""Create a step-by-step plan for this task:

Task: {state['input']}

Return a numbered list of concrete steps. Keep it simple (3-5 steps)."""
    
    response = llm.invoke([HumanMessage(content=prompt)])
    
    # Parse steps (simple parsing)
    lines = response.content.split('\n')
    steps = [line.strip() for line in lines if line.strip() and any(char.isdigit() for char in line[:3])]
    
    print(f"\n📋 PLAN CREATED:")
    for step in steps:
        print(f"  {step}")
    print()
    
    return {"plan": steps, "current_step": 0, "results": []}

# Node 2: Executor
def executor(state: HybridState) -> dict:
    """Execute the current step."""
    if state["current_step"] >= len(state["plan"]):
        # All steps done
        return {}
    
    current_step = state["plan"][state["current_step"]]
    
    print(f"⚙️ Executing: {current_step}")
    
    # Execute step (simplified - just use LLM)
    prompt = f"""Previous results: {state.get('results', [])}\n\nExecute this step: {current_step}"""
    response = llm.invoke([HumanMessage(content=prompt)])
    
    result = f"Step {state['current_step'] + 1} result: {response.content}"
    print(result)
    print(f"✓ Done\n")
    
    return {
        "results": [result],
        "current_step": state["current_step"] + 1
    }

# --- REFLECTION SUITE ---
def generator(state: HybridState):
    """Generates an initial draft from execution results"""
    print("Generating initial draft from execution results...")
    prompt = f"""Combine these research results into initial draft:
Search Results: {state['results']}
Task: {state['input']}

Write a clear, concise and accurate draft from the results"""
    response = llm.invoke([HumanMessage(content=prompt)])
    return {"draft": response.content, "iterations": 0}

def critic(state: HybridState) -> dict:
    """Assess the draft against the original task"""
    prompt = f"""Critique this summary against the original task:
Draft: {state['draft']}
Task: {state['input']}
Critique this draft. Does it fulfil the task requirements? What could be improved?
If it's excellent, say "APPROVED".
Otherwise, provide specific improvements needed."""
    print("Critiquing draft...")
    response = llm.invoke([HumanMessage(content=prompt)])
    return {"critique": response.content}

def refiner(state: HybridState):
    """Improves the draft based on critique."""
    print(f"♻️ Refining draft (Attempt {state['iterations'] + 1})...")
    prompt = f"""Improve this draft based on: 
Original Task: {state['input']}
Critique: {state['critique']}
Draft: {state['draft']}"""
    response = llm.invoke([HumanMessage(content=prompt)])
    return {"draft": response.content, "iterations": state["iterations"] + 1}

def finalizer(state: HybridState) -> dict:
    """Set final output."""
    print("\n✅ Reflection complete!\n")
    return {"final_output": state["draft"]}

print("✅ Reflection nodes defined")
# Out:
# ✅ Reflection nodes defined

# %%
def should_execute(state: HybridState):
    """Decide if more steps to execute."""
    if state["current_step"] < len(state["plan"]):
        return "executor"
    return "generator"

def should_refine(state: HybridState):
    """Decide if we need more refinement."""
    if "APPROVED" in state["critique"].upper() or state["iterations"] >= MAX_REFLECTIONS:
        return "finalizer"
    return "refiner"

# Build Graph
builder = StateGraph(HybridState)

builder.add_node("planner", planner)
builder.add_node("executor", executor)
builder.add_node("generator", generator)
builder.add_node("critic", critic)
builder.add_node("refiner", refiner)
builder.add_node("finalizer", finalizer)

builder.add_edge(START, "planner")
builder.add_edge("planner", "executor")
builder.add_conditional_edges(
    "executor", 
    should_execute, 
    {"executor": "executor", "generator": "generator"}
)
builder.add_edge("generator", "critic")
builder.add_conditional_edges(
    "critic", 
    should_refine, 
    {"refiner": "refiner", "finalizer": "finalizer"}
)
builder.add_edge("refiner", "critic") # Loop back to critic after refining
builder.add_edge("finalizer", END)

hybrid_agent = builder.compile()

# %%
task = "Analyze the usefulness of argan oil into a plain-language and make it brief"

result = hybrid_agent.invoke({
    "input": task,
    "plan": [],
    "current_step": 0,
    "results": [],
    "iterations": 0,
    "draft": "",
    "critique": ""
})

# FINAL OUTPUT PRINTING
print("\n" + "="*50)
print("📊 HYBRID AGENT EXECUTION SUMMARY")
print("="*50)
print(f"PLAN: {result['plan']}")
print(f"\nINITIAL DRAFT: {result['draft'][:100]}...")
print(f"\nCRITIQUE: {result['critique'][:100]}...")
print(f"\nFINAL OUTPUT:\n{result['final_output']}")
print("="*50)
# Out:
# 📋 PLAN CREATED:
#   1. **Research Argan Oil**: Gather information on argan oil, including its origins, production process, and common uses in cosmetics and cooking.
#   2. **Identify Benefits**: List the key benefits of argan oil, such as moisturizing properties, antioxidant content, and potential health benefits.
#   3. **Evaluate Uses**: Analyze how argan oil is used in everyday products (like skin care and hair care) and its nutritional value when used in cooking.
#   4. **Summarize Findings**: Write a brief summary that highlights the main points about argan oil's usefulness in simple language.
#   5. **Review and Edit**: Go through the summary to ensure clarity and conciseness, making any necessary adjustments for better understanding.
#
# ⚙️ Executing: 1. **Research Argan Oil**: Gather information on argan oil, including its origins, production process, and common uses in cosmetics and cooking.
# Step 1 result: ### Argan Oil: Overview
#
# **Origins:**
# Argan oil is derived from the nuts of the argan tree (Argania spinosa), which is native to Morocco. The tree is well-adapted to the arid climate of the region and has been a vital part of the local ecosystem and economy for centuries. The Berber people of Morocco have traditionally used argan oil for various purposes, including cooking, skin care, and medicinal applications.
#
# **Production Process:**
# 1. **Harvesting:** The argan nuts are harvested from the fruit of the argan tree. The fruit is typically collected in the summer months when it ripens.
# 2. **Shelling:** The outer pulp of the fruit is removed to access the hard-shelled nuts inside. This process can be labor-intensive, as the nuts are often cracked open by hand.
# 3. **Extraction:** The oil is extracted from the nuts through two main methods:
#    - **Cold Pressing:** This method involves mechanically pressing the nuts to extract the oil without the use of heat, preserving its nutritional and beneficial properties. This is the method used for cosmetic-grade argan oil.
#    - **Roasting:** For culinary argan oil, the nuts are roasted before pressing, which gives the oil a distinct nutty flavor.
# 4. **Filtering:** The extracted oil is filtered to remove any remaining solids, resulting in a clear, golden oil.
#
# **Common Uses:**
# - **Cosmetics:**
#   - **Moisturizer:** Argan oil is rich in fatty acids and vitamin E, making it an excellent moisturizer for skin and hair.
#   - **Anti-Aging:** Its antioxidant properties help reduce the appearance of fine lines and wrinkles.
#   - **Hair Care:** Used as a conditioner or treatment to add shine, reduce frizz, and promote healthy hair.
#   - **Nail Care:** Strengthens nails and softens cuticles.
#
# - **Cooking:**
#   - **Culinary Uses:** Argan oil is used in Moroccan cuisine, often drizzled over salads, couscous, or used as a dip for bread. It has a unique flavor profile that enhances various dishes.
#   - **Nutritional Benefits:** It is high in unsaturated fatty acids, antioxidants, and has anti-inflammatory properties.
#
# ### Conclusion
# Argan oil is a versatile product with a rich cultural heritage, primarily sourced from Morocco. Its production process is labor-intensive, contributing to its premium status in both cosmetic and culinary markets. The oil's numerous benefits make it a popular choice for skincare, haircare, and cooking, appealing to a wide range of consumers.
# ✓ Done
#
# ⚙️ Executing: 2. **Identify Benefits**: List the key benefits of argan oil, such as moisturizing properties, antioxidant content, and potential health benefits.
# Step 2 result: ### Key Benefits of Argan Oil
#
# 1. **Moisturizing Properties:**
#    - Argan oil is rich in fatty acids, particularly oleic and linoleic acids, which help to hydrate and nourish the skin and hair, making it an excellent moisturizer.
#
# 2. **Antioxidant Content:**
#    - The oil contains high levels of vitamin E and other antioxidants, which help to protect the skin from free radical damage, reducing signs of aging and promoting a youthful appearance.
#
# 3. **Anti-Aging Effects:**
#    - Its antioxidant properties contribute to reducing the appearance of fine lines and wrinkles, promoting skin elasticity and firmness.
#
# 4. **Hair Care Benefits:**
#    - Argan oil can improve hair health by adding shine, reducing frizz, and providing moisture. It can also help to repair damaged hair and promote overall hair strength.
#
# 5. **Nail and Cuticle Care:**
#    - The oil strengthens nails and softens cuticles, making it beneficial for nail health and appearance.
#
# 6. **Anti-Inflammatory Properties:**
#    - Argan oil has anti-inflammatory effects, which can help soothe irritated skin and reduce redness, making it suitable for sensitive skin types.
#
# 7. **Healing Properties:**
#    - It may aid in the healing of minor skin irritations and conditions, such as eczema and psoriasis, due to its nourishing and soothing qualities.
#
# 8. **Nutritional Benefits:**
#    - When used in cooking, argan oil is high in unsaturated fatty acids and antioxidants, contributing to heart health and overall well-being.
#
# 9. **Skin Barrier Protection:**
#    - Argan oil helps to strengthen the skin's natural barrier, preventing moisture loss and protecting against environmental stressors.
#
# 10. **Versatile Usage:**
#     - Its multifunctional nature allows it to be used in various applications, from skincare and haircare to culinary uses, making it a valuable addition to any beauty or cooking routine.
#
# These benefits make argan oil a sought-after ingredient in both cosmetic and culinary products, appealing to a wide range of consumers looking for natural and effective solutions.
# ✓ Done
#
# ⚙️ Executing: 3. **Evaluate Uses**: Analyze how argan oil is used in everyday products (like skin care and hair care) and its nutritional value when used in cooking.
# Step 3 result: ### Evaluation of Argan Oil Uses
#
# #### 1. **Skin Care Applications**
# Argan oil is a prominent ingredient in various skin care products due to its moisturizing and nourishing properties. Here are some common uses:
#
# - **Moisturizers:** Argan oil is often found in creams, lotions, and serums. Its high content of fatty acids, particularly oleic and linoleic acids, helps to hydrate the skin, making it suitable for all skin types, including dry and sensitive skin.
#
# - **Anti-Aging Products:** Many anti-aging formulations incorporate argan oil for its antioxidant properties. The vitamin E content helps combat free radicals, reducing the appearance of fine lines and wrinkles, and promoting a more youthful complexion.
#
# - **Facial Oils:** Pure argan oil is used as a facial oil, often applied directly to the skin or mixed with other oils. It absorbs quickly and provides deep hydration without clogging pores.
#
# - **Body Care:** Argan oil is also used in body butters and scrubs, enhancing skin softness and elasticity while providing a protective barrier against environmental stressors.
#
# #### 2. **Hair Care Applications**
# Argan oil is widely recognized for its benefits in hair care products:
#
# - **Conditioners and Treatments:** Many conditioners and hair masks contain argan oil to provide moisture, shine, and manageability. It helps to reduce frizz and improve overall hair texture.
#
# - **Styling Products:** Argan oil is often included in styling creams and serums, where it acts as a heat protectant and adds a glossy finish to styled hair.
#
# - **Scalp Treatments:** Due to its anti-inflammatory properties, argan oil can be beneficial for scalp health, helping to soothe irritation and dryness.
#
# #### 3. **Nail and Cuticle Care**
# Argan oil is also used in nail care products:
#
# - **Cuticle Oils:** It is commonly found in cuticle oils and treatments, where it helps to soften cuticles and strengthen nails, promoting healthier nail growth.
#
# #### 4. **Culinary Uses**
# When used in cooking, argan oil offers both flavor and nutritional benefits:
#
# - **Flavor Enhancer:** Culinary argan oil, often roasted before extraction, has a unique nutty flavor that enhances salads, couscous, and various dishes. It can be drizzled over meals or used as a dip for bread.
#
# - **Nutritional Value:** Argan oil is rich in unsaturated fatty acids, particularly oleic and linoleic acids, which are beneficial for heart health. It also contains antioxidants that contribute to overall well-being. Its anti-inflammatory properties may help reduce the risk of chronic diseases.
#
# - **Versatile Ingredient:** Argan oil can be used in dressings, marinades, and as a finishing oil, making it a versatile addition to a healthy diet.
#
# ### Conclusion
# Argan oil's multifaceted uses in skin care, hair care, and cooking highlight its versatility and effectiveness. Its rich composition of fatty acids, antioxidants, and anti-inflammatory properties make it a valuable ingredient in everyday products, appealing to consumers seeking natural and beneficial solutions for beauty and health. Whether used topically or ingested, argan oil offers a range of benefits that enhance both personal care and culinary experiences.
# ✓ Done
#
# ⚙️ Executing: 4. **Summarize Findings**: Write a brief summary that highlights the main points about argan oil's usefulness in simple language.
# Step 4 result: ### Summary of Findings on Argan Oil
#
# Argan oil is a natural oil extracted from the nuts of the argan tree, which is native to Morocco. It has a long history of use by the Berber people for cooking, skin care, and medicinal purposes. The oil is produced through a labor-intensive process that includes harvesting, shelling, and extracting the oil, either through cold pressing for cosmetic use or roasting for culinary use.
#
# **Key Benefits:**
# - **Moisturizing:** Argan oil is rich in fatty acids, making it an excellent moisturizer for skin and hair.
# - **Anti-Aging:** Its high vitamin E content helps reduce fine lines and wrinkles, promoting youthful skin.
# - **Hair Care:** It adds shine, reduces frizz, and improves hair health, making it a popular ingredient in hair products.
# - **Nail Care:** Argan oil strengthens nails and softens cuticles.
# - **Culinary Uses:** It has a unique nutty flavor and is nutritious, being high in healthy fats and antioxidants.
#
# Overall, argan oil is a versatile product that can be used in beauty routines and cooking, offering numerous benefits for skin, hair, and health. Its natural properties make it a sought-after ingredient for those looking for effective and holistic solutions.
# ✓ Done
#
# ⚙️ Executing: 5. **Review and Edit**: Go through the summary to ensure clarity and conciseness, making any necessary adjustments for better understanding.
# Step 5 result: ### Revised Summary of Findings on Argan Oil
#
# Argan oil is a natural oil extracted from the nuts of the argan tree (Argania spinosa), native to Morocco. It has a rich history of use by the Berber people for cooking, skin care, and medicinal purposes. The production process is labor-intensive, involving harvesting, shelling, and extracting the oil through either cold pressing for cosmetic use or roasting for culinary applications.
#
# **Key Benefits:**
# - **Moisturizing:** Argan oil is high in fatty acids, making it an excellent moisturizer for both skin and hair.
# - **Anti-Aging:** Its significant vitamin E content helps reduce the appearance of fine lines and wrinkles, promoting a youthful complexion.
# - **Hair Care:** The oil adds shine, reduces frizz, and enhances overall hair health, making it a popular ingredient in hair care products.
# - **Nail Care:** Argan oil strengthens nails and softens cuticles, contributing to healthier nail growth.
# - **Culinary Uses:** With its unique nutty flavor, argan oil is nutritious, rich in healthy fats and antioxidants, and can enhance various dishes.
#
# Overall, argan oil is a versatile product suitable for beauty routines and cooking, offering numerous benefits for skin, hair, and health. Its natural properties make it a sought-after ingredient for those seeking effective and holistic solutions.
# ✓ Done
#
# Generating initial draft from execution results...
# Critiquing draft...
# ♻️ Refining draft (Attempt 1)...
# Critiquing draft...
# ♻️ Refining draft (Attempt 2)...
# Critiquing draft...
#
# ✅ Reflection complete!
#
#
# ==================================================
# 📊 HYBRID AGENT EXECUTION SUMMARY
# ==================================================
# PLAN: ['1. **Research Argan Oil**: Gather information on argan oil, including its origins, production process, and common uses in cosmetics and cooking.', '2. **Identify Benefits**: List the key benefits of argan oil, such as moisturizing properties, antioxidant content, and potential health benefits.', '3. **Evaluate Uses**: Analyze how argan oil is used in everyday products (like skin care and hair care) and its nutritional value when used in cooking.', "4. **Summarize Findings**: Write a brief summary that highlights the main points about argan oil's usefulness in simple language.", '5. **Review and Edit**: Go through the summary to ensure clarity and conciseness, making any necessary adjustments for better understanding.']
#
# INITIAL DRAFT: ### Argan Oil: A Brief Overview
#
# Argan oil is a natural oil from the nuts of the argan tree found in...
#
# CRITIQUE: The draft provides a good overview of argan oil, highlighting its uses in skincare, haircare, and co...
#
# FINAL OUTPUT:
# ### Argan Oil: A Brief Overview
#
# Argan oil is a natural oil from the nuts of the argan tree found in Morocco. Traditionally used for cooking and skincare, it has gained popularity worldwide for its many benefits.
#
# ### Why Argan Oil is Useful
#
# - **Moisturizes Skin and Hair**: Argan oil is great for keeping your skin and hair hydrated. It helps prevent dryness and makes both feel soft and smooth.
#
# - **Reduces Aging Signs**: Rich in vitamin E, argan oil can help reduce fine lines and wrinkles, giving your skin a more youthful appearance.
#
# - **Improves Hair Health**: It adds shine and reduces frizz, making your hair look healthier and easier to manage.
#
# - **Strengthens Nails**: Using argan oil on your nails can make them stronger and promote healthier growth.
#
# - **Enhances Cooking**: With its unique nutty flavor, argan oil is not only nutritious but also a delicious addition to salads and other dishes.
#
# ### In Summary
#
# Argan oil is a versatile product that can improve your beauty routine and enhance your cooking. Its natural properties make it a practical choice for anyone looking to boost their skincare, haircare, and culinary experiences.
# ==================================================
